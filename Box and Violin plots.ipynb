# %%
# standard
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
from numpy.random import randn

#stats
from scipy import stats

#plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
url = 'http://en.wikipedia.org/wiki/Box_plot#mediaviewer/File:Boxplot_vs_PDF.svg'

# %%
data1 = randn(100)

# %%
data2 = randn(100)

# %%
sns.boxplot([data1,data2])

# %%
sns.boxplot([data1,data2],whis=np.inf) #to include outliers as well

# %%
sns.boxplot(data1,vert=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-718c883ba478> in <module>()
# ----> 1 sns.boxplot(data1,vert=True)
#
# C:\Users\swapn\Anaconda2\lib\site-packages\seaborn\categorical.pyc in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2235     kwargs.update(dict(whis=whis, notch=notch))
#    2236
# -> 2237     plotter.plot(ax, kwargs)
#    2238     return ax
#    2239
#
# C:\Users\swapn\Anaconda2\lib\site-packages\seaborn\categorical.pyc in plot(self, ax, boxplot_kws)
#     547     def plot(self, ax, boxplot_kws):
#     548         """Make the plot."""
# --> 549         self.draw_boxplot(ax, boxplot_kws)
#     550         self.annotate_axes(ax)
#     551         if self.orient == "h":
#
# C:\Users\swapn\Anaconda2\lib\site-packages\seaborn\categorical.pyc in draw_boxplot(self, ax, kws)
#     484                                          positions=[i],
#     485                                          widths=self.width,
# --> 486                                          **kws)
#     487                 color = self.colors[i]
#     488                 self.restyle_boxplot(artist_dict, color, props)
#
# TypeError: boxplot() got multiple values for keyword argument 'vert'

# %%
#normal dist
data1 = stats.norm(0,5).rvs(100)
# two gamma dist. concatenated together
data2 = np.concatenate([stats.gamma(5).rvs(50)-1,
                       -1*stats.gamma(5).rvs(50)])

#Box plot both data 1 and data 2

sns.boxplot([data1,data2],whis=np.inf)

# %%
sns.violinplot([data1,data2])

# %%
sns.violinplot(data2,bw=0.01)

# %%
sns.violinplot(data1, inner='stick')
